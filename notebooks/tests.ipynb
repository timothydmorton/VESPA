# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from vespa import transit_basic as tr
# Out:
# /u/tdm/anaconda/lib/python2.7/site-packages/setuptools-7.0-py2.7.egg/pkg_resources.py:1045: UserWarning: /u/tdm/.python-eggs is writable by group/others and vulnerable to attack when used with get_resource_filename. Consider a more secure location (set with .set_extraction_path or the PYTHON_EGG_CACHE environment variable).

# %%
mafn = tr.MAInterpolationFunction()

# %%
zs = np.linspace(0,1.2,500)
plt.plot(zs, mafn(0.1,zs))

# %%
import logging
rootLogger = logging.getLogger()
rootLogger.setLevel(logging.WARNING)

# %%
p0, b, aR = tr.eclipse_pars(10, 1.0, 0.5, 1.0, 0.5)
ts, fs = tr.eclipse(p0,b,aR, P=10, MAfn=mafn)
plt.plot(ts,fs)

dur, depth, slope = tr.eclipse_tt(p0, b, aR, P=10, MAfn=mafn)
plt.plot(ts,tr.traptransit(ts,np.array([dur,depth,slope,0])))

# %%
print dur, depth, slope
# Out:
# 0.191708658273 0.289214147953 2.93380430212

# %%
from vespa.kepler import KeplerTransitSignal

# %%
s = KeplerTransitSignal(87.01)

# %%
s.df
# Out:
#              TIME  TIMECORR  CADENCENO      SAP_FLUX  SAP_FLUX_ERR  \
# 0      120.539007  0.000855        568  301338.75000     14.351400
# 1      120.559442  0.000856        569  301317.34375     14.350985
# 2      120.579876  0.000856        570  301328.18750     14.352235
# 3      120.600310  0.000857        571  301302.81250     14.351120
# 4      120.620745  0.000858        572  301303.90625     14.351894
# 5      120.641179  0.000859        573  301323.93750     14.351185
# 6      120.661613  0.000859        574  301302.12500     14.350945
# 7      120.682048  0.000860        575  301318.18750     14.351001
# 8      120.702482  0.000861        576  301329.71875     14.351317
# 9      120.722916  0.000861        577  301289.18750     14.350432
# 10     120.743351  0.000862        578  301315.56250     14.351839
# 11     120.763785  0.000863        579  301296.53125     14.350765
# 12     120.784219  0.000864        580  301293.56250     14.351567
# ...
