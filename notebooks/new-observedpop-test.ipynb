# %%
# %matplotlib inline

from vespa.stars.populations import Observed_BinaryPopulation

import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %%
mags = {'H': 10.211,
            'J': 10.523,
            'K': 10.152000000000001}

pop = Observed_BinaryPopulation(mags=mags)
# Out:
# INFO:root:Fitting BinaryStarModel to {'H': (10.211, 0.05), 'K': (10.152000000000001, 0.05), 'J': (10.523, 0.05)}...
# INFO:root:BinaryStarModel fit Done.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-0df77ee0cea7> in <module>()
#       3             'K': 10.152000000000001}
#       4
# ----> 5 pop = Observed_BinaryPopulation(mags=mags)
#
# /u/tdm/anaconda/lib/python2.7/site-packages/VESPA-0.1.2-py2.7-linux-x86_64.egg/vespa/stars/populations.pyc in __init__(self, mags, mag_errs, Teff, logg, feh, starmodel, n, f_binary, f_triple, ichrone, bands, period, ecc, orbpop, stars, **kwargs)
#    1611                           Teff=Teff, logg=logg, feh=feh,
#    1612                           bands=bands, orbpop=orbpop,
# -> 1613                           period=period, ecc=ecc, **kwargs)
#    1614
#    1615     @property
#
# ...

# %%
from isochrones.dartmouth import Dartmouth_Isochrone

# %%
dar = Dartmouth_Isochrone()

# %%
import numpy as np
masses = np.ones(100)
dar(masses, 9.5, 0, distance=np.ones(100)*1000, AV=np.ones(100)*0.2)
# Out:
#         B_mag    D51_mag      H_mag      I_mag      J_mag      K_mag  \
# 0   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 1   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 2   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 3   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 4   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 5   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 6   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 7   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 8   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 9   15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 10  15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 11  15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# 12  15.896314  15.305111  13.468458  14.306415  13.812742  13.418787
# ...
